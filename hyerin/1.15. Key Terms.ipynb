# %% [markdown]
# - abstract data type
# 추상데이터타입
# - abstraction
# 추상화
# - algorithm
# 알고리즘
# - class
# 클래스
# - computable
# 계산가능
# - data abstraction
# 데이터 추상황
# - data structure
# 데이터 구조
# - data type
# 데이터 타입
# - deep equality
# 깊은 동등
# - dictionary
# 딕셔너리
# - encapsulation
# 캡슐화
# - exception
# 예외
# - format operator
# 포맷 연산자
# - formatted strings
# 서식문자열
# - HAS-A relationship
# HAS-A관계
# - implementation-independent
# 구현동립적
# - information hiding
# 정보은닉
# - inheritance
# 상속
# - inheritance hierarchy
# 상속계층
# - interface
# 인터페이스
# - IS-A relationship
# IS-A관계
# - list
# 리스트
# - list comprehension
# 리스트 컴프리핸션
# - method
# 메서드
# - mutability
# 가변성
# - object
# 객체
# - procedural abstraction
# 절차적 추상화
# - programming
# 프로그래밍
# - prompt
# 프롬프트
# - self
# - shallow equality
# 얕은 동등
# - simulation
# 시뮬레이션
# - string
# 문자열
# - subclass
# 자식클래스
# - superclass
# 부모클래스
# - truth table
# 진리표
