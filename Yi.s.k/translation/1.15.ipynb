# %%
1.15. Key Terms
핵심 용어
abstract data type
추상 데이터 타입
abstraction	
추상화
algorithm
알고리즘
class
클래스
computable
계산 가능
data abstraction
데이터 추상화
data structure
데이터 구조
data type
데이터 타입
deep equality
dictionary
사전
encapsulation
캡슐화
exception
예외
format operator
서식 연산자
formatted strings
서식렬
HAS-A relationship
HAS-A 관계
implementation independent
information hiding
정보 은닉
inheritance
상속
inheritance hierarchy
계승계층
interface
인터페이스
IS-A relationship
IS-A 관계
list
리스트
list comprehension
리스트 컴프리헨션(for문에서 값 빈 리스트에 넣는 방식)
method
메서드
mutability
이변성
object
객체
procedural abstraction
절차적 추상화
programming
프로그래밍
prompt
프롬프트
self
shallow equality
simulation
시뮬레이션
string
문자열
subclass
서브클래스
superclass
슈퍼클래스
truth table
진리표
