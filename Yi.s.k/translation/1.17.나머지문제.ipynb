# %%
#9. Research the __repr__ method. How does it differ from __str__? When is it used? Implement __repr__.
# str은 비공식적인 문자열, repr은 공식적인 문자열을 출력한다.
def __repr__(self):
    return "Hello" + self.title

f = 'hi hi'
print(str(f))
print(repr(f))
# Out:
# hi hi
# 'hi hi'

# %%
#10. Research other types of gates that exist (such as NAND, NOR, and XOR). Add them to the circuit hierarchy. How much additional coding did you need to do?
# NAND : AND의 부정형. NOR : OR의 부정형. XOR : 상호 배타적 OR 게이트
# return 부분에 NOT만 추가해주면 된다.
class LogicGate:

    def __init__(self,n):
        self.name = n
        self.output = None

    def getName(self):
        return self.name

    def getOutput(self):
        self.output = self.performGateLogic()
        return self.output


class BinaryGate(LogicGate):

    def __init__(self,n):
        LogicGate.__init__(self,n)

        self.pinA = None
        self.pinB = None

    def getPinA(self):
        if self.pinA == None:
            return int(input("Enter Pin A input for gate "+self.getName()+"-->"))
        else:
            return self.pinA.getFrom().getOutput()

    def getPinB(self):
        if self.pinB == None:
            return int(input("Enter Pin B input for gate "+self.getName()+"-->"))
        else:
            return self.pinB.getFrom().getOutput()

    def setNextPin(self,source):
        if self.pinA == None:
            self.pinA = source
        else:
            if self.pinB == None:
                self.pinB = source
            else:
                print("Cannot Connect: NO EMPTY PINS on this gate")


class AndGate(BinaryGate):

    def __init__(self,n):
        BinaryGate.__init__(self,n)

    def performGateLogic(self):

        a = self.getPinA()
        b = self.getPinB()
        if a==1 and b==1:
            return 1
        else:
            return 0

class OrGate(BinaryGate):

    def __init__(self,n):
        BinaryGate.__init__(self,n)

    def performGateLogic(self):

        a = self.getPinA()
        b = self.getPinB()
        if a ==1 or b==1:
            return 1
        else:
            return 0

class NandGate(BinaryGate):

    def __init__(self,n):
        BinaryGate.__init__(self,n)

    def performGateLogic(self):

        a = self.getPinA()
        b = self.getPinB()
        if a==1 and b==1:
            return 0
        else:
            return 1

class NorGate(BinaryGate):

    def __init__(self,n):
        BinaryGate.__init__(self,n)

    def performGateLogic(self):

        a = self.getPinA()
        b = self.getPinB()
        if a ==1 or b==1:
            return 0
        else:
            return 1       
        
class XorGate(BinaryGate):

    def __init__(self,n):
        BinaryGate.__init__(self,n)

    def performGateLogic(self):

        a = self.getPinA()
        b = self.getPinB()
        if a ==1 and b==1:
            return 0
        elif a == 1 or a == 1:
            return 1
        else :
            return 0
        
class UnaryGate(LogicGate):

    def __init__(self,n):
        LogicGate.__init__(self,n)

        self.pin = None

    def getPin(self):
        if self.pin == None:
            return int(input("Enter Pin input for gate "+self.getName()+"-->"))
        else:
            return self.pin.getFrom().getOutput()

    def setNextPin(self,source):
        if self.pin == None:
            self.pin = source
        else:
            print("Cannot Connect: NO EMPTY PINS on this gate")


class NotGate(UnaryGate):

    def __init__(self,n):
        UnaryGate.__init__(self,n)

    def performGateLogic(self):
        if self.getPin():
            return 0
        else:
            return 1


class Connector:

    def __init__(self, fgate, tgate):
        self.fromgate = fgate
        self.togate = tgate

        tgate.setNextPin(self)

    def getFrom(self):
        return self.fromgate

    def getTo(self):
        return self.togate


def main():
   g1 = NandGate("G1")
   g2 = NandGate("G2")
   g3 = NorGate("G3")
   g4 = XorGate("G4")
   c1 = Connector(g1,g3)
   c2 = Connector(g2,g3)
   c3 = Connector(g3,g4)
   print(g4.getOutput())

main()
# Out:
# Enter Pin A input for gate G1-->1
# Enter Pin B input for gate G1-->0
# Enter Pin A input for gate G2-->0
# Enter Pin B input for gate G2-->1
# Enter Pin B input for gate G4-->0
# 0

# %%
#11. The most simple arithmetic circuit is known as the half-adder. Research the simple half-adder circuit. Implement this circuit.
# 반가산기는 XOR와 AND게이트만으로 구성할 수 있으며, 최종값은 2C + S
class LogicGate:

    def __init__(self,n):
        self.name = n
        self.output = None

    def getName(self):
        return self.name

    def getOutput(self):
        self.output = self.performGateLogic()
        return self.output


class BinaryGate(LogicGate):

    def __init__(self,n):
        LogicGate.__init__(self,n)

        self.pinA = None
        self.pinB = None

    def getPinA(self):
        if self.pinA == None:
            return int(input("Enter Pin A input for gate "+self.getName()+"-->"))
        else:
            return self.pinA.getFrom().getOutput()

    def getPinB(self):
        if self.pinB == None:
            return int(input("Enter Pin B input for gate "+self.getName()+"-->"))
        else:
            return self.pinB.getFrom().getOutput()

    def setNextPin(self,source):
        if self.pinA == None:
            self.pinA = source
        else:
            if self.pinB == None:
                self.pinB = source
            else:
                print("Cannot Connect: NO EMPTY PINS on this gate")
                
class AndGate(BinaryGate):

    def __init__(self,n):
        BinaryGate.__init__(self,n)

    def performGateLogic(self):

        a = self.getPinA()
        b = self.getPinB()
        if a==1 and b==1:
            return 1
        else:
            return 0
        
class XorGate(BinaryGate):

    def __init__(self,n):
        BinaryGate.__init__(self,n)

    def performGateLogic(self):

        a = self.getPinA()
        b = self.getPinB()
        if a ==1 and b==1:
            return 0
        elif a == 1 or b == 1:
            return 1
        else :
            return 0
        
class half_adder(BinaryGate):
    def __init__(self,n):
        BinaryGate.__init__(self,n)
            
    def performGateLogic(self):
        return 2*(AndGate.performGateLogic(self)) +XorGate.performGateLogic(self)
    
class Connector:

    def __init__(self, fgate, tgate):
        self.fromgate = fgate
        self.togate = tgate

        tgate.setNextPin(self)

    def getFrom(self):
        return self.fromgate

    def getTo(self):
        return self.togate
    
def main():
    g1 = half_adder("G1")
    print(g1.getOutput())

main()
# Out:
# Enter Pin A input for gate G1-->0
# Enter Pin B input for gate G1-->1
# Enter Pin A input for gate G1-->0
# Enter Pin B input for gate G1-->1
# 1

# %%
# 12. Now extend that circuit and implement an 8 bit full-adder.
class fullAdder:
    def __init__(self, n, carry):
        self.name = n
        self.carry = carry
        self.pinA = None
        self.pinB = None
        self.carryOut = None
        self.sum = None
        
    def getCarry(self):
        if self.carry == None:
            self.carry = int(input("Enter Cin input for gate "+self.name+"-->"))
        return self.carry
    
    def getPinA(self):
        if self.pinA == None:
            self.pinA = int(input("Enter Pin A input for gate "+self.name+"-->"))
        return self.pinA
        
    def getPinB(self):
        if self.pinB == None:
            self.pinB =  int(input("Enter Pin B input for gate "+self.name+"-->"))
        return self.pinB
        
    def XorGate(self,a,b):
        if a ==1 and b==1:
            return 0
        elif a == 1 or b == 1:
            return 1
        else :
            return 0
    
    def AndGate(self,a,b):
        if a==1 and b==1:
            return 1
        else:
            return 0
        
    def OrGate(self,a,b):
        if a ==1 or b==1:
            return 1
        else:
            return 0
        
    def getCarryOut(self):
        self.carryOut = self.OrGate(self.AndGate(self.getPinA(),self.getPinB()),self.AndGate(self.XorGate(self.getPinA(),self.getPinB()),self.getCarry()))
        return self.carryOut
    
    def getSum(self):
        self.sum = self.XorGate(self.XorGate(self.getPinA(),self.getPinB()),self.getCarry())
        return self.sum

def eightAdder():
    add1 = fullAdder('adder1',None)
    add2 = fullAdder('adder2',add1.getCarryOut())
    add3 = fullAdder('adder3',add2.getCarryOut())
    add4 = fullAdder('adder4',add3.getCarryOut())
    add5 = fullAdder('adder5',add4.getCarryOut())
    add6 = fullAdder('adder6',add5.getCarryOut())
    add7 = fullAdder('adder7',add6.getCarryOut())
    add8 = fullAdder('adder8',add7.getCarryOut())
    print(add1.getSum())
    print(add2.getSum())
    print(add3.getSum())
    print(add4.getSum())
    print(add5.getSum())
    print(add6.getSum())
    print(add7.getSum())
    print(add8.getSum())
    print(add8.getCarryOut())
    
eightAdder()
# Out:
# Enter Pin A input for gate adder1-->1
# Enter Pin B input for gate adder1-->1
# Enter Cin input for gate adder1-->0
# Enter Pin A input for gate adder2-->0
# Enter Pin B input for gate adder2-->0
# Enter Pin A input for gate adder3-->1
# Enter Pin B input for gate adder3-->0
# Enter Pin A input for gate adder4-->1
# Enter Pin B input for gate adder4-->1
# Enter Pin A input for gate adder5-->0
# Enter Pin B input for gate adder5-->1
# Enter Pin A input for gate adder6-->1
# Enter Pin B input for gate adder6-->0
# Enter Pin A input for gate adder7-->0
# Enter Pin B input for gate adder7-->1
# 0
# 1
# 1
# 0
# 0
# 0
# 0
# Enter Pin A input for gate adder8-->1
# Enter Pin B input for gate adder8-->1
# 1
# 1

# %%
#13.The circuit simulation shown in this chapter works in a backward direction. 
#In other words, given a circuit, the output is produced by working back through the input values, which in turn cause other outputs to be queried. 
#This continues until external input lines are found, at which point the user is asked for values. 
#Modify the implementation so that the action is in the forward direction; upon receiving inputs the circuit produces an output.
class AndGate:
    def __init__(self,n):
        self.name = n
        self.output = None
        self.pinA = None
        self.pinB = None

    def getName(self):
        return self.name

    def getPinA(self):
        if self.pinA == None:
            return int(input("Enter Pin A input for gate "+self.getName()+"-->"))
        else:
            return self.pinA.getFrom().getOutput()

    def getPinB(self):
        if self.pinB == None:
            return int(input("Enter Pin B input for gate "+self.getName()+"-->"))
        else:
            return self.pinB.getFrom().getOutput()

    def setNextPin(self,source):
        if self.pinA == None:
            self.pinA = source
        else:
            if self.pinB == None:
                self.pinB = source
            else:
                print("Cannot Connect: NO EMPTY PINS on this gate")
                
    def performGateLogic(self):

        a = self.getPinA()
        b = self.getPinB()
        if a==1 and b==1:
            return 1
        else:
            return 0
    
    def getOutput(self):
        self.output = self.performGateLogic()
        return self.output

def main():
    g1 = AndGate('G1')
    print(g1.getOutput())

main()
# Out:
# Enter Pin A input for gate G1-->1
# Enter Pin B input for gate G1-->0
# 0

# %%
# 14. Design a class to represent a playing card. Now design a class to represent a deck of cards. Using these two classes, implement a favorite card game.
# 섰다(한국 포커) (플레잉카드(트럼프) 대신 화투 이용)
import random
class flowerFight:
    def __init__(self, n):
        self.name = n
        self.output = None
        
    def getName(self):
        return self.name
    
    def getResult(self):
        self.getPick2()
        self.output = self.checkMyStat()
        return self.name+"의 패 : "+self.output
    
class deck(flowerFight):
    def __init__(self, n):
        flowerFight.__init__(self,n)
        self.pick1 = 0
        self.pick2 = 0
    
    def getPick1(self):
        if (self.pick1 == 0):
            self.pick1 += random.randrange(1,21)
            print(self.pick1)
        return self.pick1
    
    def getPick2(self):
        if (self.pick2 == 0):
            self.pick2 += random.randrange(1,21)
        return self.pick2

    def betting(self):
        self.betting = int(input(self.name+"님, 게임에 베팅하시겠습니까? [다이=1/콜=2/하프=3/쿼터=4/따당=5/올인=6]"))
        if(self.betting == 1):
            print(self.name+"님이 게임을 포기했습니다.")
            return str(self.betting)
        else:
            return str(self.betting)
    
    def checkMyStat(self):
        if(self.pick1%10 == self.pick2%10):
            if(self.pick1%10 + self.pick2%10 == 0):
                return '장땡'
            else:
                return str(self.pick1%10) + '땡'
        elif(self.pick1 + self.pick2== 31):
            return '38광땡'
        elif(self.pick1 + self.pick2 == 29):
            return '18광땡'
        elif(self.pick1 + self.pick2== 24):
            return '13광땡'
        elif((self.pick1%10 == 1 and self.pick2%10 ==2)or(self.pick1%10 == 2 and self.pick2%10 ==1)):
            return '알리'
        elif((self.pick1%10 == 1 and self.pick2%10 ==4)or(self.pick1%10 == 4 and self.pick2%10 ==1)):
            return '독사'
        elif((self.pick1%10 == 1 and self.pick2%10 ==9)or(self.pick1%10 == 9 and self.pick2%10 ==1)):
            return '구삥'
        elif((self.pick1%10 == 1 and self.pick2%10 ==10)or(self.pick1%10 == 10 and self.pick2%10 ==1)):
            return '장삥'
        elif((self.pick1%10 == 4 and self.pick2%10 ==10)or(self.pick1%10 == 10 and self.pick2%10 ==4)):
            return '장사'
        elif((self.pick1%10 == 4 and self.pick2%10 ==6)or(self.pick1%10 == 6 and self.pick2%10 ==4)):
            return '쎄륙'
        else:
            if((self.pick1 + self.pick2) % 10 == 0):
                return '망통'
            else:
                return str((self.pick1 + self.pick2) % 10) +'끗'

def dual():
    a = deck('a')
    b = deck('b')
    
    a.getPick1()
    b.getPick1()
    bet1 = a.betting()
    bet2 = b.betting()
    if(bet1 != '1' and bet2 != '1'):
        print(a.getResult())
        print(b.getResult())
    
    
dual()
# Out:
# 6
# 17
# a님, 게임에 베팅하시겠습니까? [다이=1/콜=2/하프=3/쿼터=4/따당=5/올인=6]2
# b님, 게임에 베팅하시겠습니까? [다이=1/콜=2/하프=3/쿼터=4/따당=5/올인=6]2
# a의 패 : 5끗
# b의 패 : 망통

# %%
#15. Find a Sudoku puzzle in the local newspaper. Write a program to solve the puzzle.
class sudoku:
    def __init__(self,sudoku):
        self.sudoku = sudoku
        
    def checkTile(self, i, j):
        for x in range(i,9):
            for y in range(j,9):
                if self.sudoku[x][y] == 0:
                    return x,y
        for x in range(9):
            for y in range(9):
                if self.sudoku[x][y] == 0:
                    return x,y
            return -1,-1

    def isValid(self,sudoku, i, j, e):
        rowClear=9
        for x in range(9):
            if(e != self.sudoku[i][x]):
                rowClear -= 1
        if (rowClear == 0):
            columnClear = 9
            for x in range(9):
                if(e != self.sudoku[x][j]):
                    columnClear -= 1
            if (columnClear == 0):
                squareX = 3 *(i//3)
                squareY = 3 *(j//3)
                for x in range(squareX, squareX+3):
                    for y in range(squareY, squareY+3):
                        if self.sudoku[x][y] == e:
                            return False
                return True
        return False

    def solveSudoku(self, i=0, j=0):
            i,j = self.checkTile(self.sudoku, i, j)
            if i == -1:
                    return True
            for e in range(1,10):
                    if isValid(self.sudoku,i,j,e):
                            self.sudoku[i][j] = e
                            if solveSudoku(self.sudoku, i, j):
                                    return True
                            self.sudoku[i][j] = 0
            return False
        
    def getSolution(self):
        solveSudoku(self.sudoku)
        return self.sudoku
    
a = sudoku([[5,3,0,0,7,0,0,0,0],[6,0,0,1,9,5,0,0,0],[0,9,8,0,0,0,0,6,0],[8,0,0,0,6,0,0,0,3],[4,0,0,8,0,3,0,0,1],[7,0,0,0,2,0,0,0,6],[0,6,0,0,0,0,2,8,0],[0,0,0,4,1,9,0,0,5],[0,0,0,0,8,0,0,7,9]])

print(a.getSolution())
# Out:
# [[5, 3, 4, 6, 7, 8, 9, 1, 2], [6, 7, 2, 1, 9, 5, 3, 4, 8], [1, 9, 8, 3, 4, 2, 5, 6, 7], [8, 5, 9, 7, 6, 1, 4, 2, 3], [4, 2, 6, 8, 5, 3, 7, 9, 1], [7, 1, 3, 9, 2, 4, 8, 5, 6], [9, 6, 1, 5, 3, 7, 2, 8, 4], [2, 8, 7, 4, 1, 9, 6, 3, 5], [3, 4, 5, 2, 8, 6, 1, 7, 9]]
